# %%
# !pip install librosa
# Out:
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 1.0 MB/s eta 0:00:01
#    -------------------- ------------------- 0.5/1.0 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.3 MB/s eta 0:00:00
# ...

# %%
import os
import librosa
import numpy as np
import pandas as pd
import xgboost as xgb
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Function to extract MFCC features from an audio file
def extract_features(file_path):
    y, sr = librosa.load(file_path, duration=5)  # Load 5s of audio
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)  # Extract 13 MFCCs
    return np.mean(mfcc.T, axis=0)  # Compute mean across time steps

# %%
DATASET_PATH = r"C:\sandhiya\25-317\archive (1)" # <-- UPDATE THIS PATH

# Emotion labels based on RAVDESS filenames
emotion_map = {
    '01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad',
    '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised'
}

# %%
audio_files = []
labels = []

# %%
for root, dirs, files in os.walk(DATASET_PATH):
    for file in tqdm(files):
        if file.endswith(".wav"):
            file_path = os.path.join(root, file)
            emotion_code = file.split("-")[2]  # Emotion is the 3rd part in filename
            if emotion_code in emotion_map:
                audio_files.append(file_path)
                labels.append(emotion_map[emotion_code])
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 60032.98it/s]
# 0it [00:00, ?it/s]
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 19983.98it/s]

# %%
X_audio = np.array([extract_features(f) for f in audio_files])
y_audio = np.array(labels)

# %%
label_encoder = LabelEncoder()
y_audio_encoded = label_encoder.fit_transform(y_audio)

# %%
# Save the label encoder for future use
joblib.dump(label_encoder, 'label_encoder.pkl')
# Out:
# ['label_encoder.pkl']

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
scaler = StandardScaler()
X_audio_scaled = scaler.fit_transform(X_audio)

# %%
# Save scaler for future use
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
# Balance dataset using SMOTE
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_audio_resampled, y_audio_resampled = smote.fit_resample(X_audio_scaled, y_audio_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_audio_resampled, y_audio_resampled, test_size=0.2, random_state=42)

# %%
xgb_model = xgb.XGBClassifier(
    n_estimators=300,  # More trees for better learning
    max_depth=8,  # Deeper trees capture better patterns
    learning_rate=0.05,  # Lower learning rate improves stability
    subsample=0.8,  # Subsampling for better generalization
    colsample_bytree=0.8,  # Use a fraction of features per tree
    use_label_encoder=False,
    eval_metric='mlogloss'
)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:14:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
y_pred = xgb_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score

accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average="weighted")

print(f"XGBoost Speech Emotion Accuracy: {accuracy:.2f}")
print(f"F1-Score: {f1:.2f}")

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
# Out:
# XGBoost Speech Emotion Accuracy: 0.94
# F1-Score: 0.94
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.97      0.97      0.97        70
#         calm       0.95      1.00      0.97        73
#      disgust       0.89      0.94      0.92        72
#      fearful       0.94      0.97      0.96        67
#        happy       0.91      0.89      0.90        89
#      neutral       1.00      1.00      1.00        83
#          sad       0.97      0.90      0.94        81
#    surprised       0.90      0.88      0.89        80
#
#     accuracy                           0.94       615
#    macro avg       0.94      0.94      0.94       615
# weighted avg       0.94      0.94      0.94       615

# %%
# Save the trained model
joblib.dump(xgb_model, 'xgb_speech_emotion.pkl')
# Out:
# ['xgb_speech_emotion.pkl']

# %%
# Compute confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Speech Emotion Recognition")
plt.show()

# %%
# Load trained model and label encoder
xgb_model = joblib.load('xgb_speech_emotion.pkl')
label_encoder = joblib.load('label_encoder.pkl')
scaler = joblib.load('scaler.pkl')

# Test file path (Change this to an actual audio file)
test_file = r"D:\text_emotion\text_emotion\archive (1)\Actor_08\03-01-04-02-01-02-08.wav"

# Extract features, normalize, and make a prediction
test_features = extract_features(test_file).reshape(1, -1)
test_features_scaled = scaler.transform(test_features)

predicted_emotion = label_encoder.inverse_transform(xgb_model.predict(test_features_scaled))

print(f"Predicted Emotion: {predicted_emotion[0]}")
# Out:
#   Cell In[3], line 18
#     uploaded = st.file_uploader("📂 Or Upload a WAV File", type=["wav"])
#     ^
# IndentationError: unexpected indent

# %%
# 📂 Upload Button
import streamlit as st
uploaded = st.file_uploader("📂 Or Upload a WAV File", type=["wav"])

file_added = False  # Initialize outside to avoid reference error

if uploaded is not None:
    with open("temp.wav", "wb") as f:
        f.write(uploaded.read())
    st.success("✅ File uploaded successfully.")
    file_added = True
    st.session_state.audio_uploaded = True

# 🧠 Predict only if new audio is present
if file_added and os.path.exists("temp.wav"):
    feature = extract_features("temp.wav", duration=duration, sample_rate=sample_rate)
    if feature is not None:
        try:
            model = joblib.load("xgb_emotion_model.pkl")
            encoder = joblib.load("label_encoderr.pkl")
            scaler = joblib.load("scalerr.pkl")
            feature_scaled = scaler.transform([feature])
            pred = model.predict(feature_scaled)
            emotion = encoder.inverse_transform(pred)[0]
            st.success(f"🎭 Detected Emotion: **{emotion.upper()}**")
        except Exception as e:
            st.error(f"❌ Prediction failed: {e}")
    else:
        st.error("❌ Could not extract features from audio.")
elif not file_added:
    st.warning("⚠️ Please record or upload an audio file before prediction.")
# Out:
# 2025-04-13 00:33:17.221
# ...
#   command:
#
#     streamlit run D:\Users\HP\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
